# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.metrics as metrics
print(sklearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e82ff345a3cf> in <module>
#       4 import pandas as pd
#       5 import sklearn.metrics as metrics
# ----> 6 print(sklearn.__version__)
#
# NameError: name 'sklearn' is not defined

# %%
# Importing the dataset
dataset = pd.read_csv('Social_Network_Ads.csv')
dataset = dataset.drop(columns=['User ID'])

# %%
dataset.head(5)

# %%
enc = sklearn.preprocessing.OneHotEncoder()
enc.fit(dataset.iloc[:,[0]])
onehotlabels = enc.transform(dataset.iloc[:,[0]]).toarray()
genders = pd.DataFrame({'Female': onehotlabels[:, 0], 'Male': onehotlabels[:, 1]})
result = pd.concat([genders,dataset.iloc[:,1:]], axis=1, sort=False)
result.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b2463e28349a> in <module>
# ----> 1 enc = sklearn.preprocessing.OneHotEncoder()
#       2 enc.fit(dataset.iloc[:,[0]])
#       3 onehotlabels = enc.transform(dataset.iloc[:,[0]]).toarray()
#       4 genders = pd.DataFrame({'Female': onehotlabels[:, 0], 'Male': onehotlabels[:, 1]})
#       5 result = pd.concat([genders,dataset.iloc[:,1:]], axis=1, sort=False)
#
# NameError: name 'sklearn' is not defined

# %%
y=result['Purchased']
X=result.drop(columns=['Purchased'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8ca9d7e5c4fd> in <module>
# ----> 1 y=result['Purchased']
#       2 X=result.drop(columns=['Purchased'])
#
# NameError: name 'result' is not defined

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3434596f4b09> in <module>
#       2 from sklearn.model_selection import train_test_split
#       3 #from sklearn.cross_validation import train_test_split
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
#
# NameError: name 'X' is not defined

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Decision Tree Classification to the Training set
classifier = sklearn.tree.DecisionTreeClassifier(criterion = 'entropy', random_state = 100, max_depth=2)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=100, splitter='best')

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
cm = metrics.confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[64,  4],
#        [ 2, 30]])

# %%
sklearn.tree.plot_tree(classifier, filled=True)
plt.show()

# %%
accuracy= metrics.accuracy_score(y_test,y_pred)
recall = metrics.recall_score(y_test,y_pred)
precision = metrics.precision_score(y_test,y_pred)
print(accuracy,recall,precision)
# Out:
# 0.94 0.9375 0.8823529411764706
