# %% [markdown]
# # Chapter 14
# @ Imran Ahmad
#
# ## Using Lime

# %% [markdown]
# If using for the first time, install lime first.

# %%
# !pip install lime

# %% [markdown]
#  Import the necessary packages

# %%
import sklearn 
import pickle
import numpy as np
from lime.lime_tabular import LimeTabularExplainer as ex

# %%
pkl_file = open("housing.pkl","rb")
housing = pickle.load(pkl_file)
pkl_file.close()
housing['feature_names']
# Out:
# array(['crime_per_capita', 'zoning_prop', 'industrial_prop',
#        'nitrogen_oxide', 'number_of_rooms', 'old_home_prop',
#        'distance_from_city_center', 'high_way_access',
#        'property_tax_rate', 'pupil_teacher_ratio', 'low_income_prop',
#        'lower_status_prop', 'median_price_in_area'], dtype='<U25')

# %%
from sklearn.ensemble import RandomForestRegressor
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    housing.data, housing.target)

regressor = RandomForestRegressor()
regressor.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
cat_col = [i for i, col in enumerate(housing.data.T)
                        if np.unique(col).size < 10]

# %%
myexplainer = ex(X_train,
    feature_names=housing.feature_names,
    class_names=['median_price_in_area'],
    categorical_features=cat_col,
    mode='regression')

# %%
# Now explain a prediction
exp = myexplainer.explain_instance(X_test[25], regressor.predict,
        num_features=10)

exp.as_pyplot_figure()
from matplotlib import pyplot as plt
plt.tight_layout()

# %%
print(exp.as_list())
# Out:
# [('old_home_prop <= 5.90', -3.473862464614395), ('11.34 < median_price_in_area <= 16.82', -2.5716893824058245), ('low_income_prop <= 16.90', 0.6947645727413089), ('9.69 < industrial_prop <= 18.10', -0.5399956873521979), ('pupil_teacher_ratio <= 280.50', 0.5339006098113891), ('nitrogen_oxide=1', -0.4608593761423096), ('property_tax_rate=5', -0.2566733303921885), ('2.05 < high_way_access <= 3.26', 0.20683203600563427), ('crime_per_capita <= 0.08', 0.19594665261942779), ('zoning_prop <= 0.00', -0.15103932392423075)]

# %%
for i in [1, 35]:
    exp = myexplainer.explain_instance(X_test[i], regressor.predict,
            num_features=10)
    exp.as_pyplot_figure()
    plt.tight_layout()
