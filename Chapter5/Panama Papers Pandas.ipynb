# %%
import networkx as nx
import pandas as pd
import numpy as np

# %%
# Read the edge list and convert it to a network
edges = pd.read_csv("all_edges.csv")
edges
# Out:
#         START_ID                TYPE    END_ID  \
# 0       10000035  registered_address  14095990
# 1       10000044  registered_address  14091035
# 2       10000055  registered_address  14095990
# 3       10000064  registered_address  14091429
# 4       10000089  registered_address  14098253
# 5       10000091  registered_address  14091429
# 6       10000098  registered_address  14099188
# 7       10000105  registered_address  14095990
# 8       10000109  registered_address  14091429
# 9       10000297  registered_address  14095271
# 10      10000464  registered_address  14099155
# 11      10000507  registered_address  14094124
# 12      10000580  registered_address  14097397
# 13      10000581  registered_address  14092297
# 14      10000584  registered_address  14094414
# 15      10000635  registered_address  14095990
# 16      10000644  registered_address  14096319
# 17      10000670  registered_address  14108530
# 18      10000733  registered_address  14092130
# ...

# %%
edges = edges[edges["link"] != "registered address"]

# %%
edges
# Out:
#         START_ID             TYPE    END_ID  \
# 5310    11000001  intermediary_of  10208879
# 5311    11000001  intermediary_of  10198662
# 5312    11000001  intermediary_of  10159927
# 5313    11000001  intermediary_of  10165779
# 5314    11000001  intermediary_of  10152967
# 5315    11000002  intermediary_of  10005174
# 5316    11000002  intermediary_of  10008130
# 5317    11000002  intermediary_of  10011418
# 5318    11000002  intermediary_of  10010781
# 5319    11000002  intermediary_of  10188436
# 5320    11000002  intermediary_of  10183777
# 5321    11000002  intermediary_of  10193937
# 5322    11000002  intermediary_of  10090276
# 5323    11000002  intermediary_of  10059530
# 5324    11000002  intermediary_of  10055254
# 5325    11000003  intermediary_of  10077551
# 5326    11000005  intermediary_of  10211501
# 5327    11000005  intermediary_of  10010361
# 5328    11000005  intermediary_of  10009898
# 5329    11000005  intermediary_of  10011200
# ...

# %%
F = nx.from_pandas_edgelist(edges, "node_1", "node_2")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'node_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-6708d72ea9e2> in <module>
# ...
